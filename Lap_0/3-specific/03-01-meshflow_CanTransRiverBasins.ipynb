# %% [markdown]
# # Build `MESH` Model Setup for the Bow River at Calgary

# %% [markdown]
# We use the `MESHFlow` Python package to build a `MESH` model setup for the Bow River at Banff.

# %% [markdown]
# Let's start by importing the necessary libraries:

# %%
# import necessary libraries
import meshflow # version: meshflow-0.1.0.dev6

import os # python 3.10.2

# %% [markdown]
# Now, let's provide necessary information to set up the `MESH` model:

# %%
# main work path - modify
work_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))

# modify each segment to match your settings
config = {
    'riv': os.path.join(work_path, 'github-repos/community-workflows/1-geofabric/CanTrans-merit-geofabric', 'agg_MERIT_CanTrans_rivers.shp'),
    'cat': os.path.join(work_path, 'github-repos/community-workflows/1-geofabric/CanTrans-merit-geofabric', 'agg_MERIT_CanTrans_subbasins.shp'),
    'landcover': os.path.join(work_path, 'scratch/cantrans-models/gistool-outputs', 'CanTrans_model_stats_NA_NALCMS_landcover_2020_30m.csv'),
    'forcing_files': os.path.join(work_path, 'scratch/cantrans-models/casr-easymore-outputs1'),
    'forcing_vars': {
        "precipitation": "CaSR_v3.1_A_PR0_SFC",
        "shortwave_radiation": "CaSR_v3.1_P_FB_SFC",
        "longwave_radiation": "CaSR_v3.1_P_FI_SFC",
        "air_pressure": "CaSR_v3.1_P_P0_SFC",
        "specific_humidity": "CaSR_v3.1_P_HU_09975",
        "air_temperature": "CaSR_v3.1_P_TT_09975",
        "wind_speed": "CaSR_v3.1_P_UVC_09975",
    },        
    'forcing_units': {
        'precipitation': 'm/s',
        'shortwave_radiation': 'W/m^2',
        'longwave_radiation': 'W/m^2',
        'air_pressure': 'pascal',
        'specific_humidity': 'kg/kg',
        'air_temperature': 'kelvin',
        'wind_speed': 'm/s',
    },
    'main_id': 'COMID',
    'ds_main_id': 'NextDownID',
    'landcover_classes': {
        0: 'Unknown',
        1: 'Temperate or sub-polar needleleaf forest',
        2: 'Sub-polar taiga needleleaf forest',
        3: 'Tropical or sub-tropical broadleaf evergreen forest',
        4: 'Tropical or sub-tropical broadleaf deciduous forest',
        5: 'Temperate or sub-polar broadleaf deciduous forest',
        6: 'Mixed forest',
        7: 'Tropical or sub-tropical shrubland',
        8: 'Temperate or sub-polar shrubland',
        9: 'Tropical or sub-tropical grassland',
        10: 'Temperate or sub-polar grassland',
        11: 'Sub-polar or polar shrubland-lichen-moss',
        12: 'Sub-polar or polar grassland-lichen-moss',
        13: 'Sub-polar or polar barren-lichen-moss',
        14: 'Wetland',
        15: 'Cropland',
        16: 'Barren lands',
        17: 'Urban',
        18: 'Water',
        19: 'Snow and Ice',
    },
    'ddb_vars': {
        'river_slope': 'slope',
        'river_length': 'lengthkm',
        'river_class': 'order'
    },
    'ddb_units': {
        'river_slope': 'dimensionless',
        'river_length': 'kilometer',
        'river_class': 'dimensionless'
    },
    'settings': {
        'core': {
            'forcing_files': 'multiple',
            'forcing_start_date': '1980-01-01 00:00:00',
            'simulation_start_date': '1985-02-12 12:00:00',
            'simulation_end_date': '2010-05-18 18:00:00',
            'forcing_time_zone': 'UTC',
            # 'model_time_zone': 'America/Edmonton',
            'output_path': 'results',
        },
        'class_params': {
            'measurement_heights': {
                'wind_speed': 40,
                'specific_humidity': 40,
                'air_temperature': 40,
                'roughness_length': 50,
            },
            'copyright': {
                'author': 'University of Calgary',
                'location': 'University of Calgary',
            },
            'grus': {
                0: 'needleleaf',
                1: {
                    'class': 'needleleaf',
                    'LNZ0': -1.4,
                },
                2: 'needleleaf',
                3: 'broadleaf',
                4: 'broadleaf',
                5: {
                    'class': 'broadleaf',
                    'rOot': 4,
                },
                6: 'broadleaf',
                7: 'grass',
                8: 'grass',
                9: 'grass',
                10: 'grass',
                11: 'grass',
                12: 'grass',
                13: 'grass',
                14: 'water',
                15: 'crops',
                16: 'barrenland',
                17: 'urban',
                18: 'water',
                19: 'water',
            },
        },
        'hydrology_params': {
            'routing': [
                {
                    'R2N': 0.3
                },
            ],
            'hydrology': {
                5: {
                    'ZSNL': 2,
                },
            },
        },
        'run_options': {},
    },
    'outlet_value': -9999,
}

# %% [markdown]
# We can build an "instance" of the workflow class:

# %%
exp1 = meshflow.MESHWorkflow(**config)

# %% [markdown]
# And, we can run it using:

# %%
exp1.run(save_path=os.path.join(work_path, 'mesh_outputs'))
# Out:
# /home/zelalem/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/core.py:763: UserWarning: Since multiple forcing files are needed, each file will be processed and saved during initialization.
#   warnings.warn(
# /home/zelalem/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/zelalem/virtual-envs/scienv/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:138: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# ...

# %%
exp1.save(output_dir=os.path.join(work_path, 'mesh_outputs'))
